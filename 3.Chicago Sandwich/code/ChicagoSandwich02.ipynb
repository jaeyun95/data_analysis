# %%
from bs4 import BeautifulSoup
from urllib.request import Request,urlopen

url_main = "https://www.chicagomag.com"
url_sub = "/chicago-magazine/november-2012/best-sandwiches-chicago/"
url = url_main + url_sub

request = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
html = urlopen(request).read()
soup = BeautifulSoup(html,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <title>The 50 Best Sandwiches in Chicago – Chicago Magazine</title>
# <style type="text/css">			.heateorSssInstagramBackground{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 						div.heateor_sss_horizontal_sharing i.heateorSssInstagramBackground{background:#000!important;}div.heateor_sss_standard_follow_icons_container i.heateorSssInstagramBackground{background:#000;}
# 										.heateor_sss_horizontal_sharing .heateorSssSharing,.heateor_sss_standard_follow_icons_container .heateorSssSharing{
# 							background-color: #000;
# 							color: #fff;
# 						border-width: 0px;
# 			border-style: solid;
# 			border-color: transparent;
# 		}
# 				.heateor_sss_horizontal_sharing .heateorSssTCBackground{
# 			color:#666;
# 		}
# ...

# %%
soup.find_all("div","sammy")
# Out:
# [<div class="sammy" style="position: relative;">
#  <div class="sammyRank">1</div>
#  <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
#  Old Oak Tap<br/>
#  <em>Read more</em> </a></div>
#  </div>, <div class="sammy" style="position: relative;">
#  <div class="sammyRank">2</div>
#  <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/"><b>Fried Bologna</b><br/>
#  Au Cheval<br/>
#  <em>Read more</em> </a></div>
#  </div>, <div class="sammy" style="position: relative;">
#  <div class="sammyRank">3</div>
#  <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/"><b>Woodland Mushroom</b><br/>
#  Xoco<br/>
#  <em>Read more</em> </a></div>
#  </div>, <div class="sammy" style="position: relative;">
#  <div class="sammyRank">4</div>
# ...

# %%
tmp_one = soup.find_all("div","sammy")[0]
tmp_one.find(class_='sammyRank').get_text()
# Out:
# '1'

# %%
tmp_one.find(class_="sammyListing").get_text()
# Out:
# 'BLT\nOld Oak Tap\nRead more '

# %%
tmp_one.find('a')['href']
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
import re

tmp_string = tmp_one.find(class_='sammyListing').get_text()

print(re.split(('\n|\r\n'),tmp_string))
# Out:
# ['BLT', 'Old Oak Tap', 'Read more ']

# %%
rank = []
main_menu = []
cafe_name = []
url_add = []

list_soup = soup.find_all("div","sammy")

for item in list_soup:
  rank.append(item.find(class_="sammyRank").get_text())
  tmp_string = item.find(class_="sammyListing").get_text()
  main_menu.append(re.split(("\n|\r\n"),tmp_string)[0])
  cafe_name.append(re.split(("\n|\r\n"),tmp_string)[1])
  if "https://www.chicagomag.com" not in item.find('a')['href']:
    url_add.append("https://www.chicagomag.com" + item.find('a')['href'])
  else: url_add.append(item.find('a')['href'])

# %%
import pandas as pd

data = {"Rank":rank,"Menu":main_menu,"Cafe":cafe_name,"URL":url_add}
data_frame = pd.DataFrame(data)
data_frame.head()
# Out:
#   Rank  ...                                                URL
# 0    1  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 1    2  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 2    3  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 3    4  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 4    5  ...  https://www.chicagomag.com/Chicago-Magazine/No...
#
# [5 rows x 4 columns]

# %%
data_frame = pd.DataFrame(data,columns=["Rank","Cafe","Menu","URL"])
data_frame
# Out:
#    Rank  ...                                                URL
# 0     1  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 1     2  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 2     3  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 3     4  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 4     5  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 5     6  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 6     7  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 7     8  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 8     9  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 9    10  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 10   11  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 11   12  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 12   13  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# 13   14  ...  https://www.chicagomag.com/Chicago-Magazine/No...
# ...

# %%
data_frame.to_csv("/content/drive/MyDrive/data/best_sandwiches_chicago.csv",sep=",",encoding="UTF-8")
